# %%
import numpy as ns
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Read file from from path location
df = pd.read_csv('football_mini.csv')

# %%
#Have a view of dataset few lines
print(df.head())
# Out:
#    Unnamed: 0               Name  Age Nationality                 Club  \
# 0           0           L. Messi   31   Argentina         FC Barcelona
# 1           1  Cristiano Ronaldo   33    Portugal             Juventus
# 2           2          Neymar Jr   26      Brazil  Paris Saint-Germain
# 3           3             De Gea   27       Spain    Manchester United
# 4           4       K. De Bruyne   27     Belgium      Manchester City
#
#        Value    Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 0  110500000  565000       RF        84         95  ...         75         96
# 1   77000000  405000       ST        84         94  ...         85         95
# 2  118500000  290000       LW        79         87  ...         81         94
# 3   72000000  260000       GK        17         13  ...         40         68
# 4  102000000  355000      RCM        93         82  ...         79         88
#
# ...

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0         0
# Name               0
# Age                0
# Nationality        0
# Club               0
# Value              0
# Wage               0
# Position           0
# Crossing           0
# Finishing          0
# HeadingAccuracy    0
# ShortPassing       0
# Volleys            0
# Dribbling          0
# Curve              0
# FKAccuracy         0
# LongPassing        0
# BallControl        0
# Acceleration       0
# SprintSpeed        0
# Agility            0
# Reactions          0
# Balance            0
# ShotPower          0
# Jumping            0
# Stamina            0
# Strength           0
# LongShots          0
# Aggression         0
# Interceptions      0
# Positioning        0
# Vision             0
# Penalties          0
# Composure          0
# Marking            0
# StandingTackle     0
# SlidingTackle      0
# GKDiving           0
# GKHandling         0
# GKKicking          0
# GKPositioning      0
# GKReflexes         0
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0         Age         Value           Wage    Crossing  \
# count  100.000000  100.000000  1.000000e+02     100.000000  100.000000
# mean    49.500000   27.950000  5.158500e+07  195960.000000   65.350000
# std     29.011492    3.273323  1.962104e+07   94888.762094   23.101609
# min      0.000000   19.000000  4.000000e+06   21000.000000   11.000000
# 25%     24.750000   26.000000  3.750000e+07  125000.000000   57.750000
# 50%     49.500000   28.000000  4.825000e+07  182500.000000   74.000000
# 75%     74.250000   30.250000  6.212500e+07  240000.000000   82.000000
# max     99.000000   40.000000  1.185000e+08  565000.000000   93.000000
#
#         Finishing  HeadingAccuracy  ShortPassing     Volleys   Dribbling  ...  \
# count  100.000000       100.000000     100.00000  100.000000  100.000000  ...
# mean    64.780000        63.980000      77.23000   63.840000   72.970000  ...
# std     25.636771        22.595691      15.25067   24.016711   23.017541  ...
# ...

# %%
#Plot of a histogram with players age
plt.figure(figsize=(7, 5))
plt.hist(df['Age'], bins=10, color='green', edgecolor='black', alpha=0.7)
#Axes labels and title
plt.title('Histogram of Players Ages', color='blue', fontsize=12, fontweight='bold')
plt.xlabel('Age Value')
plt.ylabel('Freqeuncy')
#saving the histogram image
plt.savefig('histogram of Players Age', dpi=96)
plt.show()

# %%
#scatter plot of players Age and the thier finishig 
plt.figure(figsize=(6, 4))
plt.scatter(df['Age'], df['Finishing'], color='green', 
            edgecolor='green', alpha=0.7)
#Title and axes labeling with customizing
plt.xlabel('Age', color='black', fontweight='bold')
plt.title('Age vs Finishing', color='blue', fontsize=12, fontweight='bold' )
plt.ylabel('Finishing in %', color='black', fontsize=12, fontweight='bold')
#saving my image
plt.savefig('Age vs Finishing', dpi=96)
plt.show()

# %%
    # Boxplot plot of comparism of player abilities 
    plt.figure(figsize=(6, 4))
    plt.boxplot([df['Finishing'], df['Crossing'], df['Curve'], df['Dribbling']])
    #lable of x and y axis 
    x=[1, 2, 3, 4,]
    lables=['Fininshing', 'Crossing', 'Curve', 'Dribbling']
    plt.xticks(x, lables)
    plt.title('Players Abilities', color='blue', fontweight='bold')
    plt.ylabel('Effeciency in %', fontweight='bold')
    #saving Players Abilities image
    plt.savefig('Players Abilities', dpi=96)
    plt.show()
